# %% [markdown]
# # **EDA using LLM**
# * ChatGPT LLM (PandasLLM)
# * Gemini LLM

# %%
# !pip install -q pandas pandas-llm google-generativeai

# %%
import os
import pandas as pd
from pandas_llm import PandasLLM

# Data
# Please note that these names, ages, and donations are randomly generated
# and do not correspond to real individuals or their donations.
data = [('John Doe', 25, 50),
        ('Jane Smith', 38, 70),
        ('Alex Johnson', 45, 80),
        ('Jessica Brown', 60, 40),
        ('Michael Davis', 22, 90),
        ('Emily Wilson', 30, 60),
        ('Daniel Taylor', 35, 75),
        ('Sophia Moore', 40, 85),
        ('David Thomas', 50, 65),
        ('Olivia Jackson', 29, 55)]
df = pd.DataFrame(data, columns=['name', 'age', 'donation'])

api_key = "OPENAI Key"

conv_df = PandasLLM(data=df, llm_api_key = api_key)
result = conv_df.prompt("What is the average donation of people older than 40 who donated more than $50?")
code = conv_df.code_block

print(f"Executing the following expression of type {type(result)}:\n{code}\n\nResult is:\n {result}\n")
# Executing the following expression of type <class 'numpy.float64'>:
# result = df.loc[(df['age'] > 40) & (df['donation'] > 50), 'donation'].mean()

# Result is:
#  72.5
# Out:
# Executing the following expression of type <class 'str'>:
#
#
# Result is:
#  Please try later
# <ipython-input-33-311cbaa32ce7>:22: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   conv_df = PandasLLM(data=df, llm_api_key = api_key)

# %%
import os
import google.generativeai as genai
import pandas as pd
from getpass import getpass

# Get your Gemini API key
genai.configure(api_key="AIzaSyDmBJga0d-LmCt94RKXQNy6j8-pWaivMRo")

# Read Dataset into DataFrame
titanic = pd.read_csv("/content/titanic.csv")

# Define function to ask Gemini LLM
def ask_gemini(prompt, titanic):
    system_prompt = f"""You are a Python pandas expert.
You are given a pandas DataFrame named `titanic`. Write Python code that answers the question below.

Question: {prompt}
"""
    model = genai.GenerativeModel("models/gemini-1.5-pro-001")  # Use valid model name
    response = model.generate_content(system_prompt)
    print(response)
    code = response.text.strip("```python").strip("```")
    return code

# Ask your question
question = "How many missing values are there in the age column?"
code = ask_gemini(question, titanic)

print("🔧 Generated code:\n")
print(code)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "```python\ntitanic['Age'].isnull().sum()\n```"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0,
#           "safety_ratings": [
#             {
#               "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HATE_SPEECH",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HARASSMENT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
# ...

# %%
titanic['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyDmBJga0d-LmCt94RKXQNy6j8-pWaivMRo'

# %%
import os
import google.generativeai as genai
import pandas as pd
from getpass import getpass


# # Get your Gemini API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyDmBJga0d-LmCt94RKXQNy6j8-pWaivMRo"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# Read Dataset into DataFrame
titanic = pd.read_csv("/content/titanic.csv")

# Define function to ask Gemini LLM
def ask_gemini(prompt, titanic):
    system_prompt = f"""You are a Python pandas expert.
You are given a pandas DataFrame named `titanic`. Write Python code that answers the question below.
Assign the output to a variable called `result1`. Only return valid Python code.

Question: {prompt}
"""
    model = genai.GenerativeModel("models/gemini-1.5-pro-001")  # Use valid model name
    response = model.generate_content(system_prompt)
    code = response.text.strip("```python").strip("```")
    return code

# Ask your question
question = "How many distinct passengers are there in the dataset?"
code = ask_gemini(question, titanic)

print("🔧 Generated code:\n")
print(code)

# Execute the code
local_vars = {"titanic": titanic}
#print(local_vars)
exec(code, local_vars)
if "result1" in local_vars:
  print(local_vars["result1"])

# Show result if available
#if "result" in local_vars:
    #from IPython.display import display
    #display(local_vars["result"])
# Out:
# 🔧 Generated code:
#
#
# result1 = titanic['PassengerId'].nunique()
#
# 891

# %% [markdown]
# # Lab Task
#
# * Get your OpenAI and Gemini API keys, and execute the above code.
# * Modify the prompt and analyze the LLM's responses to various prompts.
# * Research the different versions of ChatGPT and Gemini LLMs available, and determine which version performs best for the EDA process.
# * Exlpore the PandasAI library (https://pypi.org/project/pandasai/) and how it is different from PandasLLM.
# * Apply EDA using an LLM on the following dataset.
#
# https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease

# %% [markdown]
# **lab** **task**

# %% [markdown]
# Gemini API Key=AIzaSyDmBJga0d-LmCt94RKXQNy6j8-pWaivMRo

# %% [markdown]
# Chatgpt And GeminiLLMs
#
# GPT
# Model Name | Release Date | Key Points
# GPT-1 | 2018 | First version (proof of concept, small, mostly research-only).
# GPT-2 | 2019 | Much larger, generated surprisingly human-like text. Initially withheld from full release due to "misuse concerns".
# GPT-3 | 2020 | 175 billion parameters, extremely capable at general tasks, made GPT famous.
# ChatGPT (based on GPT-3.5) | Nov 2022 | First public chatbot version — fine-tuned for dialogue.
# ChatGPT-4 | Mar 2023 | Much more reliable, nuanced, better at complex reasoning than GPT-3.5.
# ChatGPT-4 Turbo | Nov 2023 | A cheaper, faster, memory-optimized version of GPT-4 (used in ChatGPT product).
#
# GeminiLLMs
# Current Stable and Preview Models (as of April 28, 2025):
#
#     Gemini 2.5 Pro (Preview): This is currently the most advanced reasoning model in the Gemini family. It excels at complex problem-solving, coding, mathematics, and image understanding. It also boasts a large context window.
#         Model ID: gemini-2.5-pro-preview-03-25
#
# Release Date: April 9, 2025
#
#     Input Modalities: Text, Code, Images, Audio, Video
#     Output Modality: Text
#     Key Features: Enhanced thinking and reasoning, multimodal understanding, advanced coding, function calling, code execution, grounding with Google Search.
#
#
# Gemini 2.5 Flash (Experimental): This model prioritizes fast performance on complex tasks while maintaining strong performance. It's well-suited for tasks like summarization, document analysis, and data extraction where speed is important.
#
#     Model ID: gemini-2.5-flash-preview-04-17
#
# Release Date: April 17, 2025
# Input Modalities: Audio, images, videos, and text
# Output Modality: Text
# Key Features: Adaptive thinking, cost efficiency, fast performance.
#
#
# Gemini 2.0 Flash: This model aims to provide next-generation features with a focus on speed, thinking, real-time streaming, and multimodal generation.
#
#     Model ID: gemini-2.0-flash
#
# Latest Stable Version: gemini-2.0-flash-001 (Released February 5, 2025, stable until February 5, 2026)
# Input Modalities: Audio, images, videos, and text
# Output Modalities: Text, experimental image generation, and soon audio.
# Key Features: Speed, multimodal generation, suitable for a diverse variety of tasks.
#
# Gemini 2.0 Flash Lite: This is a variant of Gemini 2.0 Flash optimized for cost efficiency and low latency.
#
#     Model ID: gemini-2.0-flash-lite
#     Latest Stable Version: gemini-2.0-flash-lite-001 (Released February 25, 2025, stable until February 25, 2026)
#     Input Modalities: Audio, images, videos, and text
#     Output Modality: Text
#     Key Features: Cost efficiency, low latency.
#
# Gemini 1.5 Pro: This model is designed for complex reasoning tasks requiring more intelligence and has a very large context window.
#
#     Model ID: gemini-1.5-pro
#
# Latest Stable Version: gemini-1.5-pro-002 (Stable until September 24, 2025)
# Input Modalities: Audio, images, video, and text
#
#     Output Modality: Text
#     Key Features: Complex reasoning, long context window.
#
# Gemini 1.5 Flash: This version offers fast and versatile performance across a diverse variety of tasks.
#
#     Model ID: gemini-1.5-flash
#     Latest Stable Version: gemini-1.5-flash-002 (Stable until May 24, 2025)
#     Input Modalities: Audio, images, video, and text
#
#     Output Modality: Text
#     Key Features: Fast and versatile performance.
#
#
# Gemini 1.5 Flash-8B: This is a smaller variant of Gemini 1.5 Flash optimized for high volume and lower intelligence tasks.
#
#     Model ID: gemini-1.5-flash-8b
#
# Latest Stable Version: gemini-1.5-flash-8b-001
# Input Modalities: Audio, images, video, and text
#
#     Output Modality: Text
#     Key Features: High volume processing, lower intelligence tasks.
#
# Gemini Nano: This is Google's most efficient model, designed for on-device tasks on Android devices. It enables AI features to run locally, improving privacy and allowing for offline functionality.
#
#     Currently available on Pixel 8 Pro and Samsung S24 Series devices through the Google AI Edge SDK for Android.
#     Supports text modality, with more modalities coming in the future.
#
#         Used in features like Summarize in Recorder and Magic Compose on Pixel phones.
#         A multimodal version of Gemini Nano is available on the Pixel 9 series, enabling features like Pixel Screenshots and Call Notes without an internet connection.
#
# Retired Models (as of April 21, 2025):
#
#     Gemini 1.0 Pro (and Vision)
#
# Text-Bison
# Chat-Bison
# Code-Gecko
# TextEmbedding-Gecko (various versions)

# %% [markdown]
# **Best** **Model** **Of** **ChatGPT** **for** **EDA**

# %% [markdown]
# For the best EDA experience, use ChatGPT-4 Turbo with Advanced Data Analysis.
#
# If you just want free, GPT-3.5 can help you write the EDA code, but you have to run it yourself elsewhere.
#
# Comparison
# Model | Good for Basic EDA? | Code Execution? | Visualizations? | Advanced Insights?
# GPT-3.5 | ❌ Basic only | ❌ No | ❌ Limited | ❌ Limited
# GPT-4 (standard) | ✅ Good, no execution | ❌ No | ❌ Only code | ✅ Good
# GPT-4 Turbo + Advanced Data Analysis | ✅✅ Excellent | ✅ Yes | ✅ Yes | ✅✅ Very good

# %% [markdown]
# **Best** **Model** **of** **Gemini** **For** **EDA**

# %% [markdown]
# Best Model of Gemini for EDA
# the best performance in EDA with the Gemini family of LLMs, the current top recommendations would be Gemini 2.5 Pro (for complex analysis and multimodal data), Gemini 2.5 Flash (for a balance of performance and efficiency), and Gemini 1.5 Pro (for large datasets and strong reasoning).

# %%
# !pip install -q pandas pandas-llm google-generativeai

# %%
import os
import google.generativeai as genai
import pandas as pd
from getpass import getpass

# Get your Gemini API key
genai.configure(api_key="AIzaSyDmBJga0d-LmCt94RKXQNy6j8-pWaivMRo")

# Read Dataset into DataFrame
heart_2022_with_no_nans = pd.read_csv("/content/heart_2022_no_nans.csv")

# Define function to ask Gemini LLM
def ask_gemini(prompt, heart_2022_with_no_nans):
    system_prompt = f"""You are a Python pandas expert.
You are given a pandas DataFrame named `heart_2022_with_no_nans`. Write Python code that answers the question below.

Question: {prompt}
"""
    model = genai.GenerativeModel("models/gemini-1.5-pro-001")  # Use valid model name
    response = model.generate_content(system_prompt)
    print(response)
    code = response.text.strip("```python").strip("```")
    return code

# Ask your question
question = "How many missing values are there in the age column?"
code = ask_gemini(question, heart_2022_with_no_nans)

print("🔧 Generated code:\n")
print(code)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "```python\nheart_2022_with_no_nans['Age'].isna().sum()\n```\n"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0,
#           "safety_ratings": [
#             {
#               "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HATE_SPEECH",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HARASSMENT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
# ...

# %%
heart_2022_with_no_nans['Yes'].isnull().sum()
# Out:
# np.int64(0)

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyDmBJga0d-LmCt94RKXQNy6j8-pWaivMRo'

# %%
import os
import google.generativeai as genai
import pandas as pd
from getpass import getpass


# # Get your Gemini API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyDmBJga0d-LmCt94RKXQNy6j8-pWaivMRo"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# Read Dataset into DataFrame
heart_2022_with_no_nans = pd.read_csv("/content/heart_2022_no_nans.csv")

# Define function to ask Gemini LLM
def ask_gemini(prompt, heart_2022_with_no_nans):
    system_prompt = f"""You are a Python pandas expert.
You are given a pandas DataFrame named `heart_2022_with_no_nans`. Write Python code that answers the question below.
Assign the output to a variable called `result1`. Only return valid Python code.

Question: {prompt}
"""
    model = genai.GenerativeModel("models/gemini-1.5-pro-001")  # Use valid model name
    response = model.generate_content(system_prompt)
    code = response.text.strip("```python").strip("```")
    return code

# Ask your question
question = "How many distinct yes are there in the dataset?"
code = ask_gemini(question, heart_2022_with_no_nans)

print("🔧 Generated code:\n")
print(code)

# Execute the code
local_vars = {"heart_2022_with_no_nans": heart_2022_with_no_nans}
#print(local_vars)
exec(code, local_vars)
if "result1" in local_vars:
  print(local_vars["result1"])

# Show result if available
#if "result" in local_vars:
    #from IPython.display import display
    #display(local_vars["result"])
# Out:
# 🔧 Generated code:
#
#
# result1 = (heart_2022_with_no_nans == 'Yes').sum().sum()
#
# 491494
